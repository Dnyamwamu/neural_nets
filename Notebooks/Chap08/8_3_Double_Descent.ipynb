# %% [markdown]
# <a href="https://colab.research.google.com/github/Dnyamwamu/neural_nets/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ev1ywrxe
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ev1ywrxe
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=b7247685b342821c1e14f4ef4a1a0c87983ea12d7838e1647771dd8155df1dca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-itkngncd/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.228408, train error 82.57,  test loss 2.206486, test error 81.50
# Epoch   100, train loss 1.922326, train error 71.90,  test loss 1.764264, test error 70.45
# Epoch   200, train loss 1.916718, train error 72.20,  test loss 1.745912, test error 70.38
# Epoch   300, train loss 1.907425, train error 71.00,  test loss 1.742134, test error 69.50
# Epoch   400, train loss 1.905616, train error 72.03,  test loss 1.743187, test error 69.40
# Epoch   500, train loss 1.907255, train error 70.85,  test loss 1.737205, test error 69.32
# Epoch   600, train loss 1.903396, train error 71.62,  test loss 1.740331, test error 69.03
# Epoch   700, train loss 1.905438, train error 71.32,  test loss 1.752757, test error 69.57
# Epoch   800, train loss 1.906949, train error 71.57,  test loss 1.734160, test error 69.70
# Epoch   900, train loss 1.906551, train error 72.03,  test loss 1.744090, test error 70.40
# Training model with   4 hidden variables
# Epoch     0, train loss 2.308852, train error 89.85,  test loss 2.308356, test error 88.97
# Epoch   100, train loss 1.850577, train error 68.45,  test loss 1.717768, test error 68.62
# Epoch   200, train loss 1.794178, train error 65.82,  test loss 1.651886, test error 64.62
# Epoch   300, train loss 1.773983, train error 65.18,  test loss 1.610193, test error 64.53
# Epoch   400, train loss 1.767063, train error 65.28,  test loss 1.622177, test error 62.67
# Epoch   500, train loss 1.759429, train error 64.82,  test loss 1.608063, test error 61.90
# Epoch   600, train loss 1.756945, train error 65.25,  test loss 1.599450, test error 62.00
# Epoch   700, train loss 1.754116, train error 65.22,  test loss 1.606200, test error 61.25
# Epoch   800, train loss 1.749159, train error 64.28,  test loss 1.598952, test error 61.50
# Epoch   900, train loss 1.750336, train error 64.93,  test loss 1.614382, test error 61.50
# Training model with   6 hidden variables
# Epoch     0, train loss 2.297067, train error 88.55,  test loss 2.296537, test error 88.25
# Epoch   100, train loss 1.695861, train error 60.20,  test loss 1.520478, test error 58.58
# Epoch   200, train loss 1.647492, train error 59.25,  test loss 1.456898, test error 55.47
# Epoch   300, train loss 1.620199, train error 58.20,  test loss 1.439075, test error 54.50
# Epoch   400, train loss 1.606165, train error 57.50,  test loss 1.442522, test error 54.58
# Epoch   500, train loss 1.603743, train error 57.17,  test loss 1.432028, test error 54.55
# Epoch   600, train loss 1.608918, train error 57.22,  test loss 1.451962, test error 54.88
# Epoch   700, train loss 1.598776, train error 56.65,  test loss 1.443545, test error 55.53
# Epoch   800, train loss 1.600376, train error 56.22,  test loss 1.429411, test error 54.58
# Epoch   900, train loss 1.592422, train error 55.42,  test loss 1.447056, test error 54.70
# Training model with   8 hidden variables
# Epoch     0, train loss 2.243321, train error 82.97,  test loss 2.221097, test error 81.43
# Epoch   100, train loss 1.596525, train error 56.83,  test loss 1.464070, test error 56.30
# Epoch   200, train loss 1.544575, train error 54.28,  test loss 1.436124, test error 54.40
# Epoch   300, train loss 1.521101, train error 53.42,  test loss 1.422586, test error 53.10
# Epoch   400, train loss 1.503054, train error 53.42,  test loss 1.408859, test error 53.78
# Epoch   500, train loss 1.496973, train error 52.85,  test loss 1.415639, test error 53.50
# Epoch   600, train loss 1.492090, train error 52.33,  test loss 1.416813, test error 52.58
# Epoch   700, train loss 1.491176, train error 51.97,  test loss 1.427044, test error 53.30
# Epoch   800, train loss 1.494018, train error 52.35,  test loss 1.433380, test error 53.90
# Epoch   900, train loss 1.488788, train error 52.12,  test loss 1.424003, test error 53.17
# Training model with  10 hidden variables
# Epoch     0, train loss 2.229852, train error 82.12,  test loss 2.239992, test error 83.05
# Epoch   100, train loss 1.441888, train error 48.88,  test loss 1.260523, test error 45.88
# Epoch   200, train loss 1.394961, train error 47.25,  test loss 1.231256, test error 44.92
# Epoch   300, train loss 1.386021, train error 47.38,  test loss 1.252942, test error 46.15
# Epoch   400, train loss 1.369024, train error 45.95,  test loss 1.242280, test error 45.70
# Epoch   500, train loss 1.359311, train error 46.05,  test loss 1.242199, test error 45.40
# Epoch   600, train loss 1.353144, train error 45.97,  test loss 1.258946, test error 45.85
# Epoch   700, train loss 1.351335, train error 45.50,  test loss 1.264079, test error 46.15
# Epoch   800, train loss 1.347618, train error 45.00,  test loss 1.274740, test error 45.62
# Epoch   900, train loss 1.341764, train error 45.03,  test loss 1.271176, test error 45.78
# Training model with  14 hidden variables
# Epoch     0, train loss 2.256382, train error 84.85,  test loss 2.261173, test error 85.45
# Epoch   100, train loss 1.415777, train error 47.42,  test loss 1.311306, test error 48.12
# Epoch   200, train loss 1.334249, train error 45.22,  test loss 1.295725, test error 46.88
# Epoch   300, train loss 1.305441, train error 43.78,  test loss 1.305694, test error 47.33
# Epoch   400, train loss 1.286865, train error 42.80,  test loss 1.318670, test error 47.03
# Epoch   500, train loss 1.277636, train error 42.95,  test loss 1.329114, test error 47.03
# Epoch   600, train loss 1.268575, train error 41.85,  test loss 1.331371, test error 46.97
# Epoch   700, train loss 1.266380, train error 42.30,  test loss 1.346122, test error 46.78
# Epoch   800, train loss 1.258904, train error 42.55,  test loss 1.354224, test error 47.03
# Epoch   900, train loss 1.251983, train error 41.83,  test loss 1.354756, test error 46.65
# Training model with  18 hidden variables
# Epoch     0, train loss 2.216260, train error 82.95,  test loss 2.192932, test error 82.32
# Epoch   100, train loss 1.428583, train error 48.97,  test loss 1.408813, test error 53.88
# Epoch   200, train loss 1.283991, train error 44.92,  test loss 1.357553, test error 50.83
# Epoch   300, train loss 1.220593, train error 42.47,  test loss 1.393955, test error 50.85
# Epoch   400, train loss 1.183375, train error 40.97,  test loss 1.412773, test error 51.10
# Epoch   500, train loss 1.154875, train error 39.75,  test loss 1.440864, test error 51.05
# Epoch   600, train loss 1.146296, train error 39.35,  test loss 1.457809, test error 50.90
# Epoch   700, train loss 1.146250, train error 39.88,  test loss 1.485948, test error 51.42
# Epoch   800, train loss 1.132553, train error 39.30,  test loss 1.502620, test error 50.95
# Epoch   900, train loss 1.122526, train error 38.25,  test loss 1.510129, test error 51.20
# Training model with  22 hidden variables
# Epoch     0, train loss 2.154667, train error 79.43,  test loss 2.123644, test error 79.07
# Epoch   100, train loss 1.265626, train error 41.88,  test loss 1.299920, test error 48.95
# Epoch   200, train loss 1.154621, train error 37.50,  test loss 1.347271, test error 49.12
# Epoch   300, train loss 1.103457, train error 36.65,  test loss 1.400835, test error 50.10
# Epoch   400, train loss 1.073985, train error 36.05,  test loss 1.450539, test error 50.67
# Epoch   500, train loss 1.041100, train error 34.68,  test loss 1.470206, test error 51.20
# Epoch   600, train loss 1.037930, train error 35.70,  test loss 1.520901, test error 51.15
# Epoch   700, train loss 1.009543, train error 34.50,  test loss 1.557653, test error 50.90
# Epoch   800, train loss 0.988468, train error 33.80,  test loss 1.577897, test error 51.25
# Epoch   900, train loss 0.987237, train error 33.85,  test loss 1.614773, test error 52.50
# Training model with  26 hidden variables
# Epoch     0, train loss 2.172251, train error 80.53,  test loss 2.132193, test error 79.18
# Epoch   100, train loss 1.196232, train error 39.75,  test loss 1.427812, test error 52.42
# Epoch   200, train loss 1.034123, train error 34.05,  test loss 1.540496, test error 51.88
# Epoch   300, train loss 0.948218, train error 31.90,  test loss 1.667459, test error 52.97
# Epoch   400, train loss 0.900998, train error 30.35,  test loss 1.767769, test error 54.28
# Epoch   500, train loss 0.879238, train error 30.25,  test loss 1.861715, test error 54.67
# Epoch   600, train loss 0.847395, train error 29.32,  test loss 1.945351, test error 55.00
# Epoch   700, train loss 0.819046, train error 28.28,  test loss 2.048913, test error 56.00
# Epoch   800, train loss 0.812870, train error 27.97,  test loss 2.130829, test error 55.50
# Epoch   900, train loss 0.815568, train error 28.95,  test loss 2.219108, test error 56.47
# Training model with  30 hidden variables
# Epoch     0, train loss 2.181771, train error 81.30,  test loss 2.164257, test error 80.82
# Epoch   100, train loss 1.125997, train error 37.22,  test loss 1.331397, test error 48.75
# Epoch   200, train loss 0.955214, train error 31.97,  test loss 1.487304, test error 50.25
# Epoch   300, train loss 0.858257, train error 29.28,  test loss 1.637421, test error 50.55
# Epoch   400, train loss 0.797869, train error 27.53,  test loss 1.812878, test error 52.65
# Epoch   500, train loss 0.755735, train error 25.93,  test loss 1.986139, test error 53.17
# Epoch   600, train loss 0.754673, train error 26.07,  test loss 2.093897, test error 53.05
# Epoch   700, train loss 0.721872, train error 25.03,  test loss 2.221063, test error 54.03
# Epoch   800, train loss 0.699307, train error 24.18,  test loss 2.309659, test error 54.12
# Epoch   900, train loss 0.698222, train error 24.65,  test loss 2.379561, test error 54.12
# Training model with  35 hidden variables
# Epoch     0, train loss 2.219294, train error 80.93,  test loss 2.192932, test error 80.20
# Epoch   100, train loss 1.076904, train error 35.03,  test loss 1.441749, test error 51.47
# Epoch   200, train loss 0.845525, train error 27.55,  test loss 1.697357, test error 52.75
# Epoch   300, train loss 0.731771, train error 24.78,  test loss 2.041721, test error 55.33
# Epoch   400, train loss 0.664282, train error 22.57,  test loss 2.371711, test error 55.97
# Epoch   500, train loss 0.620142, train error 20.88,  test loss 2.677273, test error 55.88
# Epoch   600, train loss 0.578792, train error 19.97,  test loss 3.049155, test error 56.62
# Epoch   700, train loss 0.540665, train error 18.75,  test loss 3.379216, test error 58.97
# Epoch   800, train loss 0.539649, train error 18.22,  test loss 3.558241, test error 58.17
# Epoch   900, train loss 0.489038, train error 16.72,  test loss 3.729152, test error 57.70
# Training model with  40 hidden variables
# Epoch     0, train loss 2.092180, train error 79.30,  test loss 2.045913, test error 78.15
# Epoch   100, train loss 0.920909, train error 28.88,  test loss 1.470941, test error 49.83
# Epoch   200, train loss 0.631433, train error 19.97,  test loss 1.972544, test error 52.20
# Epoch   300, train loss 0.497681, train error 15.78,  test loss 2.566243, test error 53.67
# Epoch   400, train loss 0.418277, train error 13.60,  test loss 3.132156, test error 54.28
# Epoch   500, train loss 0.361430, train error 12.30,  test loss 3.784061, test error 55.28
# Epoch   600, train loss 0.302605, train error 10.20,  test loss 4.491214, test error 55.60
# Epoch   700, train loss 0.319554, train error 10.88,  test loss 5.177522, test error 56.10
# Epoch   800, train loss 0.299257, train error 10.85,  test loss 5.791734, test error 56.85
# Epoch   900, train loss 0.297199, train error 10.30,  test loss 6.275537, test error 56.67
# Training model with  45 hidden variables
# Epoch     0, train loss 2.089454, train error 77.93,  test loss 2.046986, test error 76.88
# Epoch   100, train loss 0.880278, train error 27.80,  test loss 1.449485, test error 48.47
# Epoch   200, train loss 0.560597, train error 17.00,  test loss 2.073362, test error 52.53
# Epoch   300, train loss 0.375712, train error 11.57,  test loss 2.852346, test error 54.05
# Epoch   400, train loss 0.289338, train error 8.60,  test loss 3.907853, test error 54.90
# Epoch   500, train loss 0.189982, train error 5.75,  test loss 5.041239, test error 55.03
# Epoch   600, train loss 0.168547, train error 5.85,  test loss 6.224582, test error 55.75
# Epoch   700, train loss 0.183361, train error 6.30,  test loss 7.377278, test error 56.08
# Epoch   800, train loss 0.014748, train error 0.07,  test loss 8.330287, test error 55.50
# Epoch   900, train loss 0.009603, train error 0.00,  test loss 9.004045, test error 55.42
# Training model with  50 hidden variables
# Epoch     0, train loss 2.069813, train error 75.65,  test loss 2.049486, test error 77.53
# Epoch   100, train loss 0.669976, train error 21.32,  test loss 1.583235, test error 50.33
# Epoch   200, train loss 0.320291, train error 9.03,  test loss 2.678103, test error 53.78
# Epoch   300, train loss 0.141121, train error 3.57,  test loss 4.252830, test error 54.10
# Epoch   400, train loss 0.023180, train error 0.00,  test loss 5.721050, test error 54.17
# Epoch   500, train loss 0.011461, train error 0.00,  test loss 6.584146, test error 54.28
# Epoch   600, train loss 0.007357, train error 0.00,  test loss 7.159318, test error 54.40
# Epoch   700, train loss 0.005355, train error 0.00,  test loss 7.583170, test error 54.25
# Epoch   800, train loss 0.004169, train error 0.00,  test loss 7.929555, test error 54.25
# Epoch   900, train loss 0.003384, train error 0.00,  test loss 8.220553, test error 54.33
# Training model with  55 hidden variables
# Epoch     0, train loss 2.017813, train error 75.45,  test loss 1.949190, test error 73.88
# Epoch   100, train loss 0.659919, train error 20.07,  test loss 1.613072, test error 50.47
# Epoch   200, train loss 0.245991, train error 6.12,  test loss 2.961955, test error 54.38
# Epoch   300, train loss 0.049827, train error 0.05,  test loss 4.711346, test error 55.35
# Epoch   400, train loss 0.016267, train error 0.00,  test loss 5.870513, test error 55.70
# Epoch   500, train loss 0.009130, train error 0.00,  test loss 6.535734, test error 56.10
# Epoch   600, train loss 0.006198, train error 0.00,  test loss 7.001069, test error 56.20
# Epoch   700, train loss 0.004614, train error 0.00,  test loss 7.372208, test error 56.20
# Epoch   800, train loss 0.003621, train error 0.00,  test loss 7.657617, test error 56.30
# Epoch   900, train loss 0.002959, train error 0.00,  test loss 7.904633, test error 56.15
# Training model with  60 hidden variables
# Epoch     0, train loss 2.003356, train error 74.12,  test loss 1.949095, test error 74.68
# Epoch   100, train loss 0.458574, train error 13.03,  test loss 1.897738, test error 51.85
# Epoch   200, train loss 0.075468, train error 0.30,  test loss 3.620094, test error 53.90
# Epoch   300, train loss 0.017143, train error 0.00,  test loss 4.838453, test error 54.08
# Epoch   400, train loss 0.008575, train error 0.00,  test loss 5.461319, test error 54.33
# Epoch   500, train loss 0.005557, train error 0.00,  test loss 5.887266, test error 54.80
# Epoch   600, train loss 0.004009, train error 0.00,  test loss 6.200587, test error 54.53
# Epoch   700, train loss 0.003108, train error 0.00,  test loss 6.457076, test error 54.47
# Epoch   800, train loss 0.002513, train error 0.00,  test loss 6.663307, test error 54.40
# Epoch   900, train loss 0.002101, train error 0.00,  test loss 6.843659, test error 54.42
# Training model with  70 hidden variables
# Epoch     0, train loss 2.080023, train error 75.47,  test loss 2.057751, test error 76.05
# Epoch   100, train loss 0.347817, train error 8.70,  test loss 1.854002, test error 48.90
# Epoch   200, train loss 0.030730, train error 0.00,  test loss 3.414295, test error 51.85
# Epoch   300, train loss 0.010533, train error 0.00,  test loss 4.114593, test error 51.92
# Epoch   400, train loss 0.005892, train error 0.00,  test loss 4.519926, test error 51.78
# Epoch   500, train loss 0.003994, train error 0.00,  test loss 4.798995, test error 51.67
# Epoch   600, train loss 0.002961, train error 0.00,  test loss 5.011211, test error 51.78
# Epoch   700, train loss 0.002319, train error 0.00,  test loss 5.184618, test error 51.88
# Epoch   800, train loss 0.001899, train error 0.00,  test loss 5.328826, test error 52.00
# Epoch   900, train loss 0.001599, train error 0.00,  test loss 5.454899, test error 52.00
# Training model with  80 hidden variables
# Epoch     0, train loss 2.042881, train error 76.68,  test loss 1.982555, test error 75.78
# Epoch   100, train loss 0.227430, train error 3.60,  test loss 2.045612, test error 51.65
# Epoch   200, train loss 0.020651, train error 0.00,  test loss 3.376271, test error 52.62
# Epoch   300, train loss 0.008203, train error 0.00,  test loss 3.912281, test error 52.67
# Epoch   400, train loss 0.004826, train error 0.00,  test loss 4.232256, test error 52.58
# Epoch   500, train loss 0.003332, train error 0.00,  test loss 4.464542, test error 52.70
# Epoch   600, train loss 0.002512, train error 0.00,  test loss 4.642659, test error 52.72
# Epoch   700, train loss 0.001990, train error 0.00,  test loss 4.782858, test error 52.65
# Epoch   800, train loss 0.001640, train error 0.00,  test loss 4.905447, test error 52.78
# Epoch   900, train loss 0.001387, train error 0.00,  test loss 5.012260, test error 52.70
# Training model with  90 hidden variables
# Epoch     0, train loss 2.054323, train error 76.30,  test loss 2.039283, test error 77.57
# Epoch   100, train loss 0.198008, train error 2.25,  test loss 2.258856, test error 54.28
# Epoch   200, train loss 0.017397, train error 0.00,  test loss 3.497373, test error 54.08
# Epoch   300, train loss 0.007202, train error 0.00,  test loss 3.998916, test error 54.22
# Epoch   400, train loss 0.004343, train error 0.00,  test loss 4.301361, test error 54.12
# Epoch   500, train loss 0.003013, train error 0.00,  test loss 4.518977, test error 54.00
# Epoch   600, train loss 0.002284, train error 0.00,  test loss 4.688920, test error 53.97
# Epoch   700, train loss 0.001814, train error 0.00,  test loss 4.826890, test error 54.00
# Epoch   800, train loss 0.001498, train error 0.00,  test loss 4.943302, test error 54.05
# Epoch   900, train loss 0.001268, train error 0.00,  test loss 5.044483, test error 54.03
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987913, train error 73.25,  test loss 1.933146, test error 74.28
# Epoch   100, train loss 0.097666, train error 0.20,  test loss 2.196981, test error 50.47
# Epoch   200, train loss 0.012518, train error 0.00,  test loss 3.041650, test error 50.20
# Epoch   300, train loss 0.005785, train error 0.00,  test loss 3.396731, test error 50.35
# Epoch   400, train loss 0.003609, train error 0.00,  test loss 3.622717, test error 50.33
# Epoch   500, train loss 0.002566, train error 0.00,  test loss 3.788779, test error 50.33
# Epoch   600, train loss 0.001961, train error 0.00,  test loss 3.919301, test error 50.55
# Epoch   700, train loss 0.001575, train error 0.00,  test loss 4.023368, test error 50.50
# Epoch   800, train loss 0.001308, train error 0.00,  test loss 4.113247, test error 50.55
# Epoch   900, train loss 0.001114, train error 0.00,  test loss 4.190803, test error 50.62
# Training model with 120 hidden variables
# Epoch     0, train loss 1.953640, train error 72.25,  test loss 1.892212, test error 73.03
# Epoch   100, train loss 0.052605, train error 0.00,  test loss 2.105818, test error 48.20
# Epoch   200, train loss 0.009688, train error 0.00,  test loss 2.690429, test error 48.47
# Epoch   300, train loss 0.004804, train error 0.00,  test loss 2.961096, test error 48.53
# Epoch   400, train loss 0.003063, train error 0.00,  test loss 3.134255, test error 48.53
# Epoch   500, train loss 0.002209, train error 0.00,  test loss 3.264375, test error 48.60
# Epoch   600, train loss 0.001708, train error 0.00,  test loss 3.364552, test error 48.47
# Epoch   700, train loss 0.001381, train error 0.00,  test loss 3.449069, test error 48.53
# Epoch   800, train loss 0.001153, train error 0.00,  test loss 3.521048, test error 48.47
# Epoch   900, train loss 0.000985, train error 0.00,  test loss 3.583407, test error 48.53
# Training model with 140 hidden variables
# Epoch     0, train loss 1.964564, train error 74.55,  test loss 1.911432, test error 74.78
# Epoch   100, train loss 0.036889, train error 0.00,  test loss 2.224447, test error 50.45
# Epoch   200, train loss 0.008172, train error 0.00,  test loss 2.695313, test error 50.58
# Epoch   300, train loss 0.004211, train error 0.00,  test loss 2.932180, test error 50.55
# Epoch   400, train loss 0.002738, train error 0.00,  test loss 3.083073, test error 50.75
# Epoch   500, train loss 0.001993, train error 0.00,  test loss 3.194498, test error 50.75
# Epoch   600, train loss 0.001548, train error 0.00,  test loss 3.285670, test error 50.80
# Epoch   700, train loss 0.001256, train error 0.00,  test loss 3.360490, test error 50.90
# Epoch   800, train loss 0.001052, train error 0.00,  test loss 3.424694, test error 51.05
# Epoch   900, train loss 0.000901, train error 0.00,  test loss 3.480414, test error 50.97
# Training model with 160 hidden variables
# Epoch     0, train loss 1.929700, train error 70.80,  test loss 1.861765, test error 72.12
# Epoch   100, train loss 0.029180, train error 0.00,  test loss 2.085382, test error 48.42
# Epoch   200, train loss 0.007277, train error 0.00,  test loss 2.487084, test error 48.47
# Epoch   300, train loss 0.003810, train error 0.00,  test loss 2.682083, test error 48.35
# Epoch   400, train loss 0.002496, train error 0.00,  test loss 2.812551, test error 48.20
# Epoch   500, train loss 0.001826, train error 0.00,  test loss 2.910779, test error 48.30
# Epoch   600, train loss 0.001425, train error 0.00,  test loss 2.988291, test error 48.25
# Epoch   700, train loss 0.001160, train error 0.00,  test loss 3.053490, test error 48.30
# Epoch   800, train loss 0.000973, train error 0.00,  test loss 3.109324, test error 48.28
# Epoch   900, train loss 0.000835, train error 0.00,  test loss 3.158277, test error 48.33
# Training model with 180 hidden variables
# Epoch     0, train loss 1.946269, train error 71.62,  test loss 1.890323, test error 73.75
# Epoch   100, train loss 0.024209, train error 0.00,  test loss 2.021459, test error 47.22
# Epoch   200, train loss 0.006517, train error 0.00,  test loss 2.371024, test error 47.33
# Epoch   300, train loss 0.003485, train error 0.00,  test loss 2.546841, test error 47.42
# Epoch   400, train loss 0.002303, train error 0.00,  test loss 2.663710, test error 47.30
# Epoch   500, train loss 0.001694, train error 0.00,  test loss 2.751476, test error 47.28
# Epoch   600, train loss 0.001327, train error 0.00,  test loss 2.821965, test error 47.33
# Epoch   700, train loss 0.001084, train error 0.00,  test loss 2.880319, test error 47.45
# Epoch   800, train loss 0.000911, train error 0.00,  test loss 2.930400, test error 47.40
# Epoch   900, train loss 0.000784, train error 0.00,  test loss 2.973988, test error 47.42
# Training model with 200 hidden variables
# Epoch     0, train loss 1.914392, train error 70.55,  test loss 1.842245, test error 72.10
# Epoch   100, train loss 0.020858, train error 0.00,  test loss 2.031108, test error 49.12
# Epoch   200, train loss 0.006019, train error 0.00,  test loss 2.348702, test error 48.50
# Epoch   300, train loss 0.003272, train error 0.00,  test loss 2.510740, test error 48.72
# Epoch   400, train loss 0.002186, train error 0.00,  test loss 2.621649, test error 48.67
# Epoch   500, train loss 0.001615, train error 0.00,  test loss 2.706001, test error 48.90
# Epoch   600, train loss 0.001269, train error 0.00,  test loss 2.772314, test error 48.72
# Epoch   700, train loss 0.001039, train error 0.00,  test loss 2.828670, test error 48.65
# Epoch   800, train loss 0.000875, train error 0.00,  test loss 2.876126, test error 48.72
# Epoch   900, train loss 0.000753, train error 0.00,  test loss 2.917881, test error 48.70
# Training model with 250 hidden variables
# Epoch     0, train loss 1.889132, train error 68.22,  test loss 1.833569, test error 70.47
# Epoch   100, train loss 0.017081, train error 0.00,  test loss 1.884217, test error 45.83
# Epoch   200, train loss 0.005358, train error 0.00,  test loss 2.141440, test error 45.72
# Epoch   300, train loss 0.002986, train error 0.00,  test loss 2.274662, test error 45.60
# Epoch   400, train loss 0.002016, train error 0.00,  test loss 2.366757, test error 45.70
# Epoch   500, train loss 0.001500, train error 0.00,  test loss 2.437094, test error 45.70
# Epoch   600, train loss 0.001183, train error 0.00,  test loss 2.493050, test error 45.80
# Epoch   700, train loss 0.000972, train error 0.00,  test loss 2.540130, test error 45.72
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.580393, test error 45.67
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.615968, test error 45.75
# Training model with 300 hidden variables
# Epoch     0, train loss 1.876280, train error 68.95,  test loss 1.787817, test error 70.68
# Epoch   100, train loss 0.014552, train error 0.00,  test loss 1.829052, test error 46.42
# Epoch   200, train loss 0.004849, train error 0.00,  test loss 2.043558, test error 46.47
# Epoch   300, train loss 0.002750, train error 0.00,  test loss 2.159905, test error 46.38
# Epoch   400, train loss 0.001872, train error 0.00,  test loss 2.238363, test error 46.28
# Epoch   500, train loss 0.001400, train error 0.00,  test loss 2.299468, test error 46.12
# Epoch   600, train loss 0.001109, train error 0.00,  test loss 2.348436, test error 46.22
# Epoch   700, train loss 0.000913, train error 0.00,  test loss 2.389202, test error 46.15
# Epoch   800, train loss 0.000773, train error 0.00,  test loss 2.424279, test error 46.15
# Epoch   900, train loss 0.000668, train error 0.00,  test loss 2.455224, test error 46.10
# Training model with 400 hidden variables
# Epoch     0, train loss 1.843317, train error 66.43,  test loss 1.775783, test error 69.40
# Epoch   100, train loss 0.011825, train error 0.00,  test loss 1.724736, test error 45.15
# Epoch   200, train loss 0.004211, train error 0.00,  test loss 1.892591, test error 44.58
# Epoch   300, train loss 0.002434, train error 0.00,  test loss 1.986613, test error 44.62
# Epoch   400, train loss 0.001676, train error 0.00,  test loss 2.052421, test error 44.67
# Epoch   500, train loss 0.001262, train error 0.00,  test loss 2.103052, test error 44.67
# Epoch   600, train loss 0.001005, train error 0.00,  test loss 2.144316, test error 44.62
# Epoch   700, train loss 0.000830, train error 0.00,  test loss 2.178699, test error 44.60
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.208354, test error 44.58
# Epoch   900, train loss 0.000610, train error 0.00,  test loss 2.234873, test error 44.53

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
