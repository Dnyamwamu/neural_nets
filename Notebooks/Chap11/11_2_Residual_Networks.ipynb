# %% [markdown]
# <a href="https://colab.research.google.com/github/Dnyamwamu/neural_nets/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-3i2t1nvq
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-3i2t1nvq
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=fb12a3b0f991d8cbb31fadc603bf15374de7eed61cc814748c038f7c3053113c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oxc8b_wo/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
    def __init__(self, input_size, output_size, hidden_size=100):
        super(ResidualNetwork, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, output_size)
        print("Initialized ResidualNetwork with {} parameters".format(self.count_params()))

    def count_params(self):
        return sum([p.view(-1).shape[0] for p in self.parameters()])

    def forward(self, x):
        # First layer
        h1 = self.linear1(x).relu()

        # First residual block: linear2 + ReLU, add input h1
        h2 = self.linear2(h1).relu() + h1  # Residual connection

        # Second residual block: linear3 + ReLU, add input h2
        h3 = self.linear3(h2).relu() + h2  # Residual connection

        # Output layer
        out = self.linear4(h3)
        return out

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized ResidualNetwork with 25310 parameters
# Epoch     0, train loss 1.541523, train error 59.83,  val loss 1.593002, percent error 63.80
# Epoch     1, train loss 1.238128, train error 46.12,  val loss 1.365073, percent error 54.10
# Epoch     2, train loss 1.046991, train error 38.97,  val loss 1.243205, percent error 47.40
# Epoch     3, train loss 0.929325, train error 34.65,  val loss 1.219132, percent error 47.80
# Epoch     4, train loss 0.818523, train error 30.68,  val loss 1.160129, percent error 45.80
# Epoch     5, train loss 0.728609, train error 27.03,  val loss 1.132780, percent error 41.70
# Epoch     6, train loss 0.644911, train error 23.03,  val loss 1.107370, percent error 41.70
# Epoch     7, train loss 0.553600, train error 19.05,  val loss 1.080518, percent error 38.80
# Epoch     8, train loss 0.493764, train error 17.22,  val loss 1.107031, percent error 39.50
# Epoch     9, train loss 0.411854, train error 13.70,  val loss 1.099346, percent error 39.10
# Epoch    10, train loss 0.460834, train error 16.43,  val loss 1.287589, percent error 40.30
# Epoch    11, train loss 0.398746, train error 14.57,  val loss 1.242720, percent error 41.20
# Epoch    12, train loss 0.276913, train error 8.90,  val loss 1.122283, percent error 35.90
# Epoch    13, train loss 0.263128, train error 8.65,  val loss 1.219924, percent error 37.90
# Epoch    14, train loss 0.255038, train error 9.20,  val loss 1.320510, percent error 38.20
# Epoch    15, train loss 0.178232, train error 5.20,  val loss 1.232079, percent error 36.90
# Epoch    16, train loss 0.261182, train error 9.07,  val loss 1.413388, percent error 38.20
# Epoch    17, train loss 0.211591, train error 6.75,  val loss 1.458476, percent error 38.30
# Epoch    18, train loss 0.163260, train error 5.25,  val loss 1.438816, percent error 37.00
# Epoch    19, train loss 0.144591, train error 4.32,  val loss 1.449463, percent error 36.60
# Epoch    20, train loss 0.044689, train error 0.35,  val loss 1.341589, percent error 34.80
# Epoch    21, train loss 0.028190, train error 0.03,  val loss 1.372134, percent error 35.10
# Epoch    22, train loss 0.020319, train error 0.00,  val loss 1.397365, percent error 35.00
# Epoch    23, train loss 0.016782, train error 0.00,  val loss 1.424880, percent error 34.30
# Epoch    24, train loss 0.014668, train error 0.00,  val loss 1.436921, percent error 34.20
# Epoch    25, train loss 0.013133, train error 0.00,  val loss 1.467605, percent error 33.80
# Epoch    26, train loss 0.011977, train error 0.00,  val loss 1.485370, percent error 34.20
# Epoch    27, train loss 0.011327, train error 0.00,  val loss 1.490430, percent error 34.30
# Epoch    28, train loss 0.009936, train error 0.00,  val loss 1.515319, percent error 34.00
# Epoch    29, train loss 0.009280, train error 0.00,  val loss 1.519598, percent error 34.10
# Epoch    30, train loss 0.008733, train error 0.00,  val loss 1.541289, percent error 34.40
# Epoch    31, train loss 0.008191, train error 0.00,  val loss 1.549564, percent error 34.50
# Epoch    32, train loss 0.007619, train error 0.00,  val loss 1.559572, percent error 34.00
# Epoch    33, train loss 0.007176, train error 0.00,  val loss 1.566145, percent error 34.00
# Epoch    34, train loss 0.006789, train error 0.00,  val loss 1.576522, percent error 34.10
# Epoch    35, train loss 0.006457, train error 0.00,  val loss 1.591954, percent error 34.40
# Epoch    36, train loss 0.006141, train error 0.00,  val loss 1.599740, percent error 33.90
# Epoch    37, train loss 0.005842, train error 0.00,  val loss 1.607711, percent error 34.20
# Epoch    38, train loss 0.005586, train error 0.00,  val loss 1.617379, percent error 34.20
# Epoch    39, train loss 0.005385, train error 0.00,  val loss 1.626920, percent error 34.10
# Epoch    40, train loss 0.005237, train error 0.00,  val loss 1.630069, percent error 34.10
# Epoch    41, train loss 0.005130, train error 0.00,  val loss 1.634353, percent error 34.30
# Epoch    42, train loss 0.005032, train error 0.00,  val loss 1.637913, percent error 34.30
# Epoch    43, train loss 0.004934, train error 0.00,  val loss 1.642827, percent error 34.30
# Epoch    44, train loss 0.004845, train error 0.00,  val loss 1.646124, percent error 33.90
# Epoch    45, train loss 0.004755, train error 0.00,  val loss 1.650787, percent error 34.60
# Epoch    46, train loss 0.004679, train error 0.00,  val loss 1.654606, percent error 34.10
# Epoch    47, train loss 0.004590, train error 0.00,  val loss 1.656096, percent error 34.50
# Epoch    48, train loss 0.004510, train error 0.00,  val loss 1.659340, percent error 34.70
# Epoch    49, train loss 0.004432, train error 0.00,  val loss 1.662925, percent error 34.50
# Epoch    50, train loss 0.004356, train error 0.00,  val loss 1.665993, percent error 34.40
# Epoch    51, train loss 0.004283, train error 0.00,  val loss 1.670486, percent error 34.60
# Epoch    52, train loss 0.004213, train error 0.00,  val loss 1.673287, percent error 34.50
# Epoch    53, train loss 0.004145, train error 0.00,  val loss 1.677201, percent error 34.40
# Epoch    54, train loss 0.004081, train error 0.00,  val loss 1.680257, percent error 34.30
# Epoch    55, train loss 0.004014, train error 0.00,  val loss 1.682006, percent error 34.40
# Epoch    56, train loss 0.003953, train error 0.00,  val loss 1.686934, percent error 34.30
# Epoch    57, train loss 0.003891, train error 0.00,  val loss 1.689532, percent error 34.50
# Epoch    58, train loss 0.003833, train error 0.00,  val loss 1.692458, percent error 34.60
# Epoch    59, train loss 0.003775, train error 0.00,  val loss 1.696581, percent error 34.50
# Epoch    60, train loss 0.003746, train error 0.00,  val loss 1.697767, percent error 34.50
# Epoch    61, train loss 0.003718, train error 0.00,  val loss 1.698308, percent error 34.50
# Epoch    62, train loss 0.003690, train error 0.00,  val loss 1.700672, percent error 34.40
# Epoch    63, train loss 0.003663, train error 0.00,  val loss 1.701390, percent error 34.60
# Epoch    64, train loss 0.003638, train error 0.00,  val loss 1.702979, percent error 34.60
# Epoch    65, train loss 0.003611, train error 0.00,  val loss 1.703917, percent error 34.50
# Epoch    66, train loss 0.003586, train error 0.00,  val loss 1.705965, percent error 34.50
# Epoch    67, train loss 0.003560, train error 0.00,  val loss 1.707144, percent error 34.50
# Epoch    68, train loss 0.003535, train error 0.00,  val loss 1.708386, percent error 34.40
# Epoch    69, train loss 0.003511, train error 0.00,  val loss 1.710371, percent error 34.50
# Epoch    70, train loss 0.003486, train error 0.00,  val loss 1.710833, percent error 34.40
# Epoch    71, train loss 0.003462, train error 0.00,  val loss 1.712626, percent error 34.50
# Epoch    72, train loss 0.003439, train error 0.00,  val loss 1.714309, percent error 34.50
# Epoch    73, train loss 0.003416, train error 0.00,  val loss 1.715237, percent error 34.40
# Epoch    74, train loss 0.003393, train error 0.00,  val loss 1.716720, percent error 34.40
# Epoch    75, train loss 0.003370, train error 0.00,  val loss 1.717477, percent error 34.50
# Epoch    76, train loss 0.003348, train error 0.00,  val loss 1.719159, percent error 34.50
# Epoch    77, train loss 0.003326, train error 0.00,  val loss 1.720856, percent error 34.40
# Epoch    78, train loss 0.003304, train error 0.00,  val loss 1.721780, percent error 34.40
# Epoch    79, train loss 0.003283, train error 0.00,  val loss 1.723694, percent error 34.40
# Epoch    80, train loss 0.003271, train error 0.00,  val loss 1.723908, percent error 34.40
# Epoch    81, train loss 0.003261, train error 0.00,  val loss 1.724575, percent error 34.40
# Epoch    82, train loss 0.003250, train error 0.00,  val loss 1.725291, percent error 34.40
# Epoch    83, train loss 0.003240, train error 0.00,  val loss 1.726057, percent error 34.40
# Epoch    84, train loss 0.003229, train error 0.00,  val loss 1.726532, percent error 34.40
# Epoch    85, train loss 0.003219, train error 0.00,  val loss 1.727025, percent error 34.40
# Epoch    86, train loss 0.003209, train error 0.00,  val loss 1.727724, percent error 34.50
# Epoch    87, train loss 0.003199, train error 0.00,  val loss 1.728481, percent error 34.40
# Epoch    88, train loss 0.003188, train error 0.00,  val loss 1.728899, percent error 34.50
# Epoch    89, train loss 0.003178, train error 0.00,  val loss 1.729694, percent error 34.40
# Epoch    90, train loss 0.003168, train error 0.00,  val loss 1.730364, percent error 34.40
# Epoch    91, train loss 0.003159, train error 0.00,  val loss 1.730855, percent error 34.40
# Epoch    92, train loss 0.003149, train error 0.00,  val loss 1.731575, percent error 34.40
# Epoch    93, train loss 0.003139, train error 0.00,  val loss 1.732116, percent error 34.30
# Epoch    94, train loss 0.003129, train error 0.00,  val loss 1.732662, percent error 34.40
# Epoch    95, train loss 0.003119, train error 0.00,  val loss 1.733329, percent error 34.50
# Epoch    96, train loss 0.003109, train error 0.00,  val loss 1.733668, percent error 34.50
# Epoch    97, train loss 0.003100, train error 0.00,  val loss 1.734659, percent error 34.50
# Epoch    98, train loss 0.003090, train error 0.00,  val loss 1.735070, percent error 34.50
# Epoch    99, train loss 0.003081, train error 0.00,  val loss 1.735721, percent error 34.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?

# %%
class PlainMLP(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=100):
        super().__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h1 = self.linear1(x).relu()
        h2 = self.linear2(h1).relu()
        h3 = self.linear3(h2).relu()
        out = self.linear4(h3)
        return out

model_plain = PlainMLP(40, 10)
model_plain.apply(weights_init)
# Out:
# PlainMLP(
#   (linear1): Linear(in_features=40, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=100, bias=True)
#   (linear3): Linear(in_features=100, out_features=100, bias=True)
#   (linear4): Linear(in_features=100, out_features=10, bias=True)
# )
