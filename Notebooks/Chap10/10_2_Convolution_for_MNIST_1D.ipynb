# %% [markdown]
# <a href="https://colab.research.google.com/github/Dnyamwamu/neural_nets/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-p3j6zocs
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-p3j6zocs
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=5c9db903d9c37b1931d813772297465cd86e707c1383e37aa5d819d91a6891fc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8wkk409d/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
import torch.nn as nn

model = nn.Sequential(
    # 1. Conv1D layer: input channels=1, output channels=15, kernel size=3, stride=2, no padding
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 2. Conv1D layer: input channels=15, output channels=15, kernel size=3, stride=2, no padding
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 3. Conv1D layer: input channels=15, output channels=15, kernel size=3, stride=2, no padding
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # Flatten layer
    nn.Flatten(),  # converts shape (batch, 15, 4) → (batch, 60)

    # Linear layer to output 10 classes
    nn.Linear(in_features=60, out_features=10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.152110, train error 84.32,  val loss 2.159536, percent error 86.10
# Epoch     1, train loss 1.840538, train error 71.50,  val loss 1.858737, percent error 72.40
# Epoch     2, train loss 1.520758, train error 63.65,  val loss 1.540959, percent error 67.00
# Epoch     3, train loss 1.292999, train error 51.60,  val loss 1.286574, percent error 53.90
# Epoch     4, train loss 1.295498, train error 51.75,  val loss 1.327236, percent error 51.80
# Epoch     5, train loss 1.133389, train error 45.75,  val loss 1.134766, percent error 47.60
# Epoch     6, train loss 1.241951, train error 47.65,  val loss 1.273219, percent error 48.70
# Epoch     7, train loss 0.990867, train error 39.95,  val loss 1.009570, percent error 41.40
# Epoch     8, train loss 0.894784, train error 35.53,  val loss 0.934500, percent error 38.80
# Epoch     9, train loss 0.786187, train error 30.88,  val loss 0.828986, percent error 33.00
# Epoch    10, train loss 0.737633, train error 29.38,  val loss 0.779238, percent error 31.20
# Epoch    11, train loss 0.621023, train error 23.07,  val loss 0.677220, percent error 26.70
# Epoch    12, train loss 0.525408, train error 19.60,  val loss 0.587441, percent error 23.10
# Epoch    13, train loss 0.551808, train error 21.50,  val loss 0.650004, percent error 24.40
# Epoch    14, train loss 0.412957, train error 15.03,  val loss 0.508164, percent error 20.00
# Epoch    15, train loss 0.415287, train error 15.15,  val loss 0.521574, percent error 19.30
# Epoch    16, train loss 0.359647, train error 13.80,  val loss 0.457951, percent error 17.80
# Epoch    17, train loss 0.450542, train error 17.18,  val loss 0.582708, percent error 20.20
# Epoch    18, train loss 0.338620, train error 13.47,  val loss 0.497734, percent error 18.50
# Epoch    19, train loss 0.298688, train error 10.55,  val loss 0.442744, percent error 16.90
# Epoch    20, train loss 0.260174, train error 10.15,  val loss 0.426485, percent error 15.30
# Epoch    21, train loss 0.203847, train error 6.68,  val loss 0.362518, percent error 12.50
# Epoch    22, train loss 0.196176, train error 7.05,  val loss 0.378091, percent error 13.40
# Epoch    23, train loss 0.214062, train error 8.40,  val loss 0.396834, percent error 13.50
# Epoch    24, train loss 0.176111, train error 5.75,  val loss 0.361682, percent error 11.80
# Epoch    25, train loss 0.169241, train error 6.22,  val loss 0.381970, percent error 13.00
# Epoch    26, train loss 0.207097, train error 7.53,  val loss 0.405564, percent error 12.80
# Epoch    27, train loss 0.176084, train error 6.22,  val loss 0.377830, percent error 11.70
# Epoch    28, train loss 0.185981, train error 6.90,  val loss 0.398063, percent error 12.70
# Epoch    29, train loss 0.147278, train error 5.05,  val loss 0.361021, percent error 11.40
# Epoch    30, train loss 0.155246, train error 5.68,  val loss 0.366255, percent error 11.50
# Epoch    31, train loss 0.144412, train error 4.75,  val loss 0.372140, percent error 11.00
# Epoch    32, train loss 0.135037, train error 4.95,  val loss 0.364688, percent error 11.40
# Epoch    33, train loss 0.134717, train error 4.68,  val loss 0.380860, percent error 11.40
# Epoch    34, train loss 0.149671, train error 5.50,  val loss 0.401466, percent error 12.10
# Epoch    35, train loss 0.123725, train error 4.18,  val loss 0.377268, percent error 12.10
# Epoch    36, train loss 0.108337, train error 3.62,  val loss 0.359546, percent error 10.30
# Epoch    37, train loss 0.098073, train error 3.28,  val loss 0.341573, percent error 9.80
# Epoch    38, train loss 0.099128, train error 3.32,  val loss 0.387434, percent error 11.30
# Epoch    39, train loss 0.109479, train error 3.85,  val loss 0.356596, percent error 10.40
# Epoch    40, train loss 0.079772, train error 2.45,  val loss 0.350757, percent error 10.10
# Epoch    41, train loss 0.071369, train error 2.03,  val loss 0.350266, percent error 9.50
# Epoch    42, train loss 0.072292, train error 1.93,  val loss 0.357888, percent error 9.80
# Epoch    43, train loss 0.073945, train error 2.30,  val loss 0.366303, percent error 10.30
# Epoch    44, train loss 0.076982, train error 2.20,  val loss 0.385610, percent error 11.10
# Epoch    45, train loss 0.072950, train error 2.18,  val loss 0.377050, percent error 9.60
# Epoch    46, train loss 0.064637, train error 1.82,  val loss 0.375805, percent error 10.60
# Epoch    47, train loss 0.068033, train error 2.03,  val loss 0.399091, percent error 10.40
# Epoch    48, train loss 0.060223, train error 1.50,  val loss 0.379592, percent error 9.80
# Epoch    49, train loss 0.059017, train error 1.47,  val loss 0.379581, percent error 9.70
# Epoch    50, train loss 0.060062, train error 1.60,  val loss 0.375214, percent error 10.00
# Epoch    51, train loss 0.058741, train error 1.60,  val loss 0.381590, percent error 10.60
# Epoch    52, train loss 0.057591, train error 1.62,  val loss 0.390768, percent error 9.50
# Epoch    53, train loss 0.054220, train error 1.25,  val loss 0.383496, percent error 9.70
# Epoch    54, train loss 0.052991, train error 1.32,  val loss 0.394279, percent error 9.20
# Epoch    55, train loss 0.055666, train error 1.57,  val loss 0.401345, percent error 10.00
# Epoch    56, train loss 0.053337, train error 1.43,  val loss 0.410976, percent error 9.70
# Epoch    57, train loss 0.050663, train error 1.30,  val loss 0.391798, percent error 9.00
# Epoch    58, train loss 0.053300, train error 1.40,  val loss 0.401254, percent error 9.80
# Epoch    59, train loss 0.051601, train error 1.32,  val loss 0.413988, percent error 10.30
# Epoch    60, train loss 0.044396, train error 0.97,  val loss 0.413950, percent error 10.00
# Epoch    61, train loss 0.045072, train error 1.10,  val loss 0.411076, percent error 10.30
# Epoch    62, train loss 0.043227, train error 0.88,  val loss 0.413066, percent error 10.10
# Epoch    63, train loss 0.042579, train error 0.97,  val loss 0.413546, percent error 10.20
# Epoch    64, train loss 0.042675, train error 0.85,  val loss 0.414088, percent error 10.50
# Epoch    65, train loss 0.043649, train error 0.93,  val loss 0.423240, percent error 9.80
# Epoch    66, train loss 0.040628, train error 0.78,  val loss 0.418674, percent error 9.90
# Epoch    67, train loss 0.039742, train error 0.90,  val loss 0.426668, percent error 10.10
# Epoch    68, train loss 0.043114, train error 0.90,  val loss 0.427994, percent error 10.50
# Epoch    69, train loss 0.039833, train error 0.75,  val loss 0.420770, percent error 10.20
# Epoch    70, train loss 0.039040, train error 0.80,  val loss 0.434729, percent error 10.40
# Epoch    71, train loss 0.038282, train error 0.70,  val loss 0.431598, percent error 9.50
# Epoch    72, train loss 0.037707, train error 0.75,  val loss 0.433342, percent error 9.80
# Epoch    73, train loss 0.038289, train error 0.62,  val loss 0.432115, percent error 10.10
# Epoch    74, train loss 0.036626, train error 0.62,  val loss 0.433913, percent error 10.10
# Epoch    75, train loss 0.035565, train error 0.57,  val loss 0.437330, percent error 9.90
# Epoch    76, train loss 0.042868, train error 1.10,  val loss 0.445264, percent error 10.00
# Epoch    77, train loss 0.036303, train error 0.70,  val loss 0.444941, percent error 9.70
# Epoch    78, train loss 0.034419, train error 0.62,  val loss 0.437651, percent error 10.20
# Epoch    79, train loss 0.034982, train error 0.62,  val loss 0.442664, percent error 9.70
# Epoch    80, train loss 0.033369, train error 0.57,  val loss 0.444442, percent error 9.90
# Epoch    81, train loss 0.033526, train error 0.62,  val loss 0.442967, percent error 10.20
# Epoch    82, train loss 0.033235, train error 0.55,  val loss 0.444386, percent error 10.00
# Epoch    83, train loss 0.032476, train error 0.47,  val loss 0.444119, percent error 10.30
# Epoch    84, train loss 0.032200, train error 0.45,  val loss 0.446837, percent error 10.10
# Epoch    85, train loss 0.032024, train error 0.53,  val loss 0.446061, percent error 10.00
# Epoch    86, train loss 0.032338, train error 0.47,  val loss 0.450698, percent error 10.20
# Epoch    87, train loss 0.032042, train error 0.50,  val loss 0.450555, percent error 10.00
# Epoch    88, train loss 0.031373, train error 0.47,  val loss 0.448289, percent error 10.10
# Epoch    89, train loss 0.031859, train error 0.50,  val loss 0.450262, percent error 10.40
# Epoch    90, train loss 0.031117, train error 0.40,  val loss 0.451138, percent error 10.20
# Epoch    91, train loss 0.030990, train error 0.45,  val loss 0.451832, percent error 10.20
# Epoch    92, train loss 0.030786, train error 0.40,  val loss 0.453463, percent error 10.20
# Epoch    93, train loss 0.030818, train error 0.47,  val loss 0.453658, percent error 10.20
# Epoch    94, train loss 0.030870, train error 0.43,  val loss 0.454345, percent error 10.30
# Epoch    95, train loss 0.030182, train error 0.43,  val loss 0.456833, percent error 10.20
# Epoch    96, train loss 0.030253, train error 0.45,  val loss 0.457372, percent error 9.90
# Epoch    97, train loss 0.030085, train error 0.43,  val loss 0.458443, percent error 9.90
# Epoch    98, train loss 0.029668, train error 0.40,  val loss 0.458309, percent error 10.00
# Epoch    99, train loss 0.029544, train error 0.40,  val loss 0.460001, percent error 10.10
